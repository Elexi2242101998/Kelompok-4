# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 
from sklearn.linear_model import LinearRegression
from IPython.display import display, HTML
import plotly.express as px
from matplotlib.ticker import StrMethodFormatter
print("Setup Complete")
# Out:
# Setup Complete

# %%
data = pd.read_excel('Python-Training.xlsx')

data.head(5)
# Out:
#    Year  Version Version Rel_Date  \
# 0  1991     0.90       1991-02-20
# 1  1992     0.90       1991-02-20
# 2  1993     0.90       1991-02-20
# 3  1994     1.00       1994-01-26
# 4  1994     1.10       1994-10-11
#
#                                       Added Features  Num Users
# 0                         Initial release of Python.    3000.00
# 1                                                NaN    5000.00
# 2                                                NaN    9530.00
# 3  New features for functional programming, inclu...   15430.00
# 4  "with" statement, ternary conditional operator...   26500.00

# %%
def scroll_table(df, table_id, title):
    html = f'<h3>{title}</h3>'
    html += f'<div id="{table_id}" style="height:200px; overflow:auto;">'
    html += df.to_html()
    html += '</div>'
    return html

# %%
def make_data_table(dataset, title):
    graph = dataset.select_dtypes(include=[np.number])
    info_graph = scroll_table(dataset, 'graph_data_2', title)
    display(HTML(info_graph))
    return make_data_table

make_data_table(data, 'Data')
# Out:
# <h3>Data</h3><div id="graph_data_2" style="height:200px; overflow:auto;"><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Year</th>
#       <th>Version</th>
#       <th>Version Rel_Date</th>
#       <th>Added Features</th>
#       <th>Num Users</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1991</td>
#       <td>0.90</td>
#       <td>1991-02-20</td>
#       <td>Initial release of Python.</td>
#       <td>3000.00</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1992</td>
#       <td>0.90</td>
#       <td>1991-02-20</td>
#       <td>NaN</td>
#       <td>5000.00</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1993</td>
#       <td>0.90</td>
#       <td>1991-02-20</td>
#       <td>NaN</td>
#       <td>9530.00</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1994</td>
#       <td>1.00</td>
#       <td>1994-01-26</td>
#       <td>New features for functional programming, including lambda, map, filter and reduce.</td>
#       <td>15430.00</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1994</td>
#       <td>1.10</td>
#       <td>1994-10-11</td>
#       <td>"with" statement, ternary conditional operator, "yield from" delegation for generators, exception chaining, relative and conditional package imports, string formatting improvements, the "sorted()" function, the "set" built-in data type</td>
#       <td>26500.00</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>1995</td>
#       <td>1.20</td>
#       <td>1995-04-13</td>
#       <td>"email" and "mimetypes" modules, improvements to the Windows port, extensions to the Tkinter GUI toolkit</td>
#       <td>34600.00</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>1995</td>
#       <td>1.30</td>
#       <td>1995-10-13</td>
#       <td>"marshal" and "pickle" modules for object serialization, improvements to the "time" module</td>
#       <td>64250.00</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>1996</td>
#       <td>1.40</td>
#       <td>1996-10-25</td>
#       <td>Modula-3 style keyword arguments and support for complex number operations.</td>
#       <td>95420.00</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>1997</td>
#       <td>1.40</td>
#       <td>1996-10-25</td>
#       <td>NaN</td>
#       <td>105400.00</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>1998</td>
#       <td>1.50</td>
#       <td>1998-01-03</td>
#       <td>Support for arbitrary-length integers, and a new garbage collection system.</td>
#       <td>160300.00</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>1999</td>
#       <td>1.50</td>
#       <td>1998-01-03</td>
#       <td>NaN</td>
#       <td>270540.00</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>2000</td>
#       <td>1.60</td>
#       <td>2000-09-05</td>
#       <td>An updated core with improvements to performance and stability.</td>
#       <td>390760.00</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>2000</td>
#       <td>2.00</td>
#       <td>2000-10-16</td>
#       <td>List comprehensions, garbage collection, Unicode support, and improved class definition syntax.</td>
#       <td>475000.00</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>2001</td>
#       <td>2.10</td>
#       <td>2001-04-15</td>
#       <td>Added support for nested scopes to perform more like other statically scoped languages</td>
#       <td>612500.00</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>2001</td>
#       <td>2.20</td>
#       <td>2001-12-21</td>
#       <td>Unified types and classes into one Python hierarchy to make Python more object-oriented. Also, added generator routines that control the behavior of loops.</td>
#       <td>694300.00</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>2002</td>
#       <td>2.20</td>
#       <td>2001-12-21</td>
#       <td>Generator expressions, unified types and classes, and the "try/except/finally" syntax.</td>
#       <td>823540.00</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>2003</td>
#       <td>2.30</td>
#       <td>2003-06-29</td>
#       <td>NaN</td>
#       <td>970830.00</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>2004</td>
#       <td>2.40</td>
#       <td>2004-11-30</td>
#       <td>Generator functions, decorator syntax, and the "with" statement for resource management.</td>
#       <td>1020450.00</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>2005</td>
#       <td>2.40</td>
#       <td>2004-11-30</td>
#       <td>NaN</td>
#       <td>1950000.00</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>2006</td>
#       <td>2.50</td>
#       <td>2006-09-19</td>
#       <td>Security Fixes</td>
#       <td>2200000.00</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>2007</td>
#       <td>2.50</td>
#       <td>2006-09-19</td>
#       <td>NaN</td>
#       <td>2956400.00</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>2008</td>
#       <td>2.60</td>
#       <td>2008-10-01</td>
#       <td>New "io" module, improvements to Python's SSL support, and the "collections" module.</td>
#       <td>3104500.00</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>2008</td>
#       <td>3.00</td>
#       <td>2008-12-03</td>
#       <td>Completely redesigned language with new syntax and backwards incompatible changes.</td>
#       <td>3405700.00</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>2009</td>
#       <td>3.10</td>
#       <td>2009-06-27</td>
#       <td>Security Fixes</td>
#       <td>3700000.00</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>2010</td>
#       <td>2.70</td>
#       <td>2010-07-03</td>
#       <td>New unittest features including test skipping, new assert methods, and test discovery</td>
#       <td>4001000.00</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>2011</td>
#       <td>3.20</td>
#       <td>2011-02-20</td>
#       <td>enhanced serialization with the "pickle" module, flexible command-line argument parsing with "argparse," and updated decimal handling capabilities</td>
#       <td>4420000.00</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>2012</td>
#       <td>3.30</td>
#       <td>2012-09-29</td>
#       <td>"yield from" syntax for delegating to subgenerators.</td>
#       <td>4940000.00</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>2013</td>
#       <td>3.30</td>
#       <td>2012-09-29</td>
#       <td>NaN</td>
#       <td>5260000.00</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>2014</td>
#       <td>3.40</td>
#       <td>2014-03-16</td>
#       <td>A new "asyncio" module for asynchronous programming.</td>
#       <td>6049000.00</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>2015</td>
#       <td>3.50</td>
#       <td>2015-09-13</td>
#       <td>"async" and "await" syntax for coroutines, improvements to the "asyncio" module.</td>
#       <td>6443500.00</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>2016</td>
#       <td>3.60</td>
#       <td>2016-12-23</td>
#       <td>f-strings, formatted string literals, and type annotations.</td>
#       <td>6838000.00</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>2017</td>
#       <td>3.60</td>
#       <td>2016-12-23</td>
#       <td>NaN</td>
#       <td>8679000.00</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>2018</td>
#       <td>3.70</td>
#       <td>2018-06-27</td>
#       <td>Data classes, Context Variables, and postponed evaluation of annotations.</td>
#       <td>10520000.00</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>2019</td>
#       <td>3.80</td>
#       <td>2019-10-14</td>
#       <td>Assignment expressions ("walrus operator"), positional-only arguments, and the "importlib.metadata" module.</td>
#       <td>11309000.00</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>2020</td>
#       <td>3.90</td>
#       <td>2020-10-05</td>
#       <td>Dictionary updates, merged dictionaries, and new syntax for Union types.</td>
#       <td>12098000.00</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>2021</td>
#       <td>3.10</td>
#       <td>2021-10-04</td>
#       <td>Pattern matching ("match" statement), error pattern matching, and structural pattern matching.</td>
#       <td>13150000.00</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>2022</td>
#       <td>3.11</td>
#       <td>2022-10-24</td>
#       <td>New installation resolver, and more improvements on pattern matching and opti
# <function __main__.make_data_table(dataset, title)>

# %%
y = data['Num Users']
X = data['Year']

fig, ax = plt.subplots()
ax.plot(y,X)
plt.title('Number of Users Over Time')
plt.ylabel('Year')
plt.xlabel('Number of Users')
plt.show()

# %%
heatmap = data.set_index('Num Users')
topi=heatmap.iloc[:20,:]
topi_f = topi.loc[:,['Year', 'Version']]

plt.figure(figsize=(15,10))
sns.heatmap(data=topi_f, annot=True)
plt.show()

# %%
ax = data.hist(column='Version', bins=25, grid=False, figsize=(12,8), color='#86bf91', zorder=2, rwidth=0.9)

ax = ax[0]
for x in ax:

    # Despine
    x.spines['right'].set_visible(False)
    x.spines['top'].set_visible(False)
    x.spines['left'].set_visible(False)

    # Switch off ticks
    x.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

    # Draw horizontal axis lines
    vals = x.get_yticks()
    for tick in vals:
        x.axhline(y=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

    # Remove title
    x.set_title("Versions by Usage")

    # Set x-axis label
    x.set_xlabel("Version Number", labelpad=20, weight='bold', size=12)

    # Set y-axis label
    x.set_ylabel("Usage", labelpad=20, weight='bold', size=12)

    # Format y-axis label
    x.yaxis.set_major_formatter(StrMethodFormatter('{x:,g}'))

# %%
# Create a linear regression model
model = LinearRegression()

# Fit the model to the data
model.fit(data[['Year']], data['Num Users'])

# Generate future years starting from the next year after the maximum year in the dataset
future_years = np.array([[year] for year in range(data['Year'].max() + 1, data['Year'].max() + 100)])

# Predict the future of the target column for the specified future years
future_target = model.predict(future_years)

# Create a DataFrame with future years as the index column and the predicted target values
future_df = pd.DataFrame(future_target, index=future_years.flatten(), columns=['Num Users'])
future_df.index.name = 'Year'

print(future_df)
# Out:
#        Num Users
# Year
# 2025 12759544.45
# 2026 13224313.51
# 2027 13689082.58
# 2028 14153851.65
# 2029 14618620.71
# ...          ...
# 2119 56447836.61
# 2120 56912605.67
# 2121 57377374.74
# 2122 57842143.80
# 2123 58306912.87
#
# [99 rows x 1 columns]

# %%
lines = future_df.plot.line()

# %%
future_df.to_csv('Python_Future.csv', index=False)
print("Output Generated Successfully")
# Out:
# Output Generated Successfully

# %%
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement janestreet (from versions: none)
# ERROR: No matching distribution found for janestreet
